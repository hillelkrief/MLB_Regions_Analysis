# %%
import pandas as pd
import numpy as np
import os

# %%
batters=pd.read_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/final after region/batters_region.csv',index_col=False)

# %%
pitchers=pd.read_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/final after region/pitchers_region.csv',index_col=False)

# %%
batters.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'name_common', 'age', 'mlb_ID', 'bbrefID',
#        'yearID', 'teamID', 'stint_ID', 'lg_ID', 'PA', 'G_x', 'Inn', 'WAR',
#        'WAR_def', 'WAR_off', 'WAR_rep', 'salary', 'pitcher', 'OPS_plus',
#        'TOB_lg', 'TB_lg', 'playerID', 'stint', 'lgID_x', 'G_y', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH',
#        'SF', 'GIDP', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'nameFirst', 'nameLast', 'nameGiven',
#        'weight', 'height', 'bats', 'throws', 'debut', 'finalGame', 'retroID',
#        'lgID_y', 'G_all', 'GS', 'G_batting', 'G_defense', 'G_p', 'G_c', 'G_1b',
#        'G_2b', 'G_3b', 'G_ss', 'G_lf', 'G_cf', 'G_rf', 'G_of', 'G_dh', 'G_ph',
#        'G_pr', 'gameNum', 'gameID', 'lgID', 'GP', 'startingPos', '_merge',
#        'region'],
#       dtype='object')

# %%
pitchers.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'playerID', 'yearID', 'stint', 'teamID',
#        'lgID_x', 'W', 'L', 'G_x', 'GS_x', 'CG', 'SHO', 'SV', 'IPouts', 'H',
#        'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP',
#        'GF', 'R', 'SH', 'SF', 'GIDP', 'birthYear', 'birthMonth', 'birthDay',
#        'birthCountry', 'birthState', 'birthCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'lgID_y', 'G_all', 'GS_y', 'G_batting',
#        'G_defense', 'G_p', 'G_c', 'G_1b', 'G_2b', 'G_3b', 'G_ss', 'G_lf',
#        'G_cf', 'G_rf', 'G_of', 'G_dh', 'G_ph', 'G_pr', 'name_common', 'age',
#        'mlb_ID', 'stint_ID', 'lg_ID', 'G_y', 'GS', 'runs_above_avg', 'WAR',
#        'salary', 'WAA', 'WAA_adj', 'WAR_rep', 'ERA_plus', 'ER_lg', 'gameNum',
#        'gameID', 'lgID', 'GP', 'startingPos', '_merge', 'region'],
#       dtype='object')

# %%
batters.value_counts('region')
# Out:
# region
# US Born       28924
# Latin Born     7154
# Other           438
# dtype: int64

# %%
pitchers.value_counts('region')
# Out:
# region
# US Born       27746
# Latin Born     4814
# Other           678
# dtype: int64

# %%
#The goal is to now aggregate our data to show the differences between specific statistics from players coming from differnt regions

# %%
All_Batters_career_SUM = batters.groupby('playerID').agg({
    'WAR': 'sum',
    'HR': 'sum',
    'GP': 'sum',
    'H': 'sum',
    'playerID':'count',
    'region': 'first'
})

# %%
#Renaming GP column to represent ASG and playerID to represent seasons played
All_Batters_career_SUM = All_Batters_career_SUM.rename(columns={'GP': 'ASG'})
All_Batters_career_SUM = All_Batters_career_SUM.rename(columns={'playerID': 'seasonsPlayed'})

# %%
All_Batters_career_SUM
# Out:
#               WAR   HR   ASG     H  seasonsPlayed      region
# playerID
# aaronha01  105.72  570  16.0  2659             17     US Born
# aaronto01   -2.77   13   0.0   216              7     US Born
# abadan01    -0.35    0   0.0     2              3     US Born
# abbotje01   -1.44   18   0.0   157              5     US Born
# abbotku01    0.54   62   0.0   523             10     US Born
# ...           ...  ...   ...   ...            ...         ...
# zuletju01   -0.19    9   0.0    43              2  Latin Born
# zuninmi01   10.62  141   0.0   518              9     US Born
# zupcibo01   -0.71    7   0.0   199              5     US Born
# zupofr01     0.12    0   0.0     2              1     US Born
# zuvelpa01   -2.36    2   0.0   109              9     US Born
#
# [5429 rows x 6 columns]

# %%
#Batter WAR average
BatterWarAvg=All_Batters_career_SUM.groupby('region').agg({'WAR': ['mean']})
BatterWarAvg
# Out:
#                  WAR
#                 mean
# region
# Latin Born  5.564268
# Other       4.331667
# US Born     5.860175

# %%
#Batter WAR average for WAR above 0
BatterWarAvgAdj=All_Batters_career_SUM[All_Batters_career_SUM['WAR'] > 0].groupby('region').agg({'WAR': ['mean']})
BatterWarAvgAdj
# Out:
#                   WAR
#                  mean
# region
# Latin Born  10.837213
# Other        7.705000
# US Born     10.802619

# %%
#HR average for HR's above 0
HRAvgAdj=All_Batters_career_SUM[All_Batters_career_SUM['HR'] > 0].groupby('region').agg({'HR': ['mean']})
HRAvgAdj
# Out:
#                    HR
#                  mean
# region
# Latin Born  55.405276
# Other       39.890625
# US Born     55.524309

# %%
#HR average
HRAvg=All_Batters_career_SUM.groupby('region').agg({'HR': ['mean']})
HRAvg
# Out:
#                    HR
#                  mean
# region
# Latin Born  43.923954
# Other       30.392857
# US Born     44.427207

# %%
#allstar average
ASGBatters=All_Batters_career_SUM.groupby('region').agg({'ASG': ['mean']})
ASGBatters
# Out:
#                  ASG
#                 mean
# region
# Latin Born  0.316540
# Other       0.226190
# US Born     0.253203

# %%
#allstar average for all stars above 0
ASGBattersAdj=All_Batters_career_SUM[All_Batters_career_SUM['ASG'] > 0].groupby('region').agg({'ASG': ['mean']})
ASGBattersAdj
# Out:
#                  ASG
#                 mean
# region
# Latin Born  2.622047
# Other       2.714286
# US Born     2.600478

# %%
#Season Played average
SPAverage=All_Batters_career_SUM.groupby('region').agg({'seasonsPlayed': ['mean']})
SPAverage
# Out:
#            seasonsPlayed
#                     mean
# region
# Latin Born      6.800380
# Other           5.214286
# US Born         6.737480

# %%
#Season Played average for seaons above 1
SPAverageAdj=All_Batters_career_SUM[All_Batters_career_SUM['seasonsPlayed'] > 0].groupby('region').agg({'seasonsPlayed': ['mean']})
SPAverageAdj
# Out:
#            seasonsPlayed
#                     mean
# region
# Latin Born      6.800380
# Other           5.214286
# US Born         6.737480

# %%
All_Batters_career_SUM.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/batters_sum_clean.csv')

# %%
All_Pitchers_career_SUM.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/pitchers_sum_clean.csv')

# %%
BatterWarAvg.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/BatterWarAvg.csv')

# %%
BatterWarAvgAdj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/BatterWarAvgAdj.csv')

# %%
HRAvgAdj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/HRAvgAdj.csv')

# %%
HRAvg.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/HRAvg.csv')

# %%
ASGBattersAdj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ASGBattersAdj.csv')

# %%
ASGBatters.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ASGBatters.csv')

# %%
SPAverage.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/SPAverage.csv')

# %%
SPAverageAdj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/SPAverageAdj.csv')

# %%
#Now, we'll do the same for pitchers

# %%
pitchers.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'playerID', 'yearID', 'stint', 'teamID',
#        'lgID_x', 'W', 'L', 'G_x', 'GS_x', 'CG', 'SHO', 'SV', 'IPouts', 'H',
#        'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP',
#        'GF', 'R', 'SH', 'SF', 'GIDP', 'birthYear', 'birthMonth', 'birthDay',
#        'birthCountry', 'birthState', 'birthCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'lgID_y', 'G_all', 'GS_y', 'G_batting',
#        'G_defense', 'G_p', 'G_c', 'G_1b', 'G_2b', 'G_3b', 'G_ss', 'G_lf',
#        'G_cf', 'G_rf', 'G_of', 'G_dh', 'G_ph', 'G_pr', 'name_common', 'age',
#        'mlb_ID', 'stint_ID', 'lg_ID', 'G_y', 'GS', 'runs_above_avg', 'WAR',
#        'salary', 'WAA', 'WAA_adj', 'WAR_rep', 'ERA_plus', 'ER_lg', 'gameNum',
#        'gameID', 'lgID', 'GP', 'startingPos', '_merge', 'region'],
#       dtype='object')

# %%
All_Pitchers_career_SUM = pitchers.groupby('playerID').agg({
    'WAR': 'sum',
    'ERA_plus': 'mean',
    'G_all': 'sum',
    'playerID':'count',
    'GP': 'sum',
    'region': 'first'
})

All_Pitchers_career_SUM
# Out:
#              WAR    ERA_plus  G_all  playerID   GP      region
# playerID
# aardsda01   1.85   94.744369    331         9  0.0     US Born
# aasedo01   15.09  126.585193    448        13  1.0     US Born
# abadfe01    3.18  116.022263    400        11  0.0  Latin Born
# abbotco01  -0.40   63.615385      8         1  0.0     US Born
# abbotgl01   5.26   97.366300    248        12  0.0     US Born
# ...          ...         ...    ...       ...  ...         ...
# zitoba01   33.05  103.277974    434        15  2.0     US Born
# zobribe01   0.03         NaN     47         1  0.0     US Born
# zuberty01  -0.12   94.390000     54         2  0.0     US Born
# zumayjo01   4.17  145.361990    171         5  0.0     US Born
# zychto01    1.59  147.576667     70         3  0.0     US Born
#
# [6257 rows x 6 columns]

# %%
All_Pitchers_career_SUM = All_Pitchers_career_SUM.rename(columns={'playerID': 'seasonsPlayed'})

All_Pitchers_career_SUM = All_Pitchers_career_SUM.rename(columns={'GP': 'ASG'})
All_Pitchers_career_SUM
# Out:
#              WAR    ERA_plus  G_all  seasonsPlayed  ASG      region
# playerID
# aardsda01   1.85   94.744369    331              9  0.0     US Born
# aasedo01   15.09  126.585193    448             13  1.0     US Born
# abadfe01    3.18  116.022263    400             11  0.0  Latin Born
# abbotco01  -0.40   63.615385      8              1  0.0     US Born
# abbotgl01   5.26   97.366300    248             12  0.0     US Born
# ...          ...         ...    ...            ...  ...         ...
# zitoba01   33.05  103.277974    434             15  2.0     US Born
# zobribe01   0.03         NaN     47              1  0.0     US Born
# zuberty01  -0.12   94.390000     54              2  0.0     US Born
# zumayjo01   4.17  145.361990    171              5  0.0     US Born
# zychto01    1.59  147.576667     70              3  0.0     US Born
#
# [6257 rows x 6 columns]

# %%
#Pitcher WAR average
PitcherWarAvg=All_Pitchers_career_SUM.groupby('region').agg({'WAR': ['mean']})
PitcherWarAvg
# Out:
#                  WAR
#                 mean
# region
# Latin Born  2.912429
# Other       3.460278
# US Born     3.546338

# %%
#Pitcher WAR average above 0
PitcherWarAvgAdj=All_Pitchers_career_SUM[All_Pitchers_career_SUM['WAR']>0].groupby('region').agg({'WAR': ['mean']})
PitcherWarAvgAdj
# Out:
#                  WAR
#                 mean
# region
# Latin Born  5.403965
# Other       6.179176
# US Born     6.192207

# %%
#ERA Plus Average
ERA_Plus_Average=All_Pitchers_career_SUM.groupby('region').agg({'ERA_plus': ['mean']})
ERA_Plus_Average
# Out:
#              ERA_plus
#                  mean
# region
# Latin Born  96.873331
# Other       97.590697
# US Born     96.532296

# %%
#ERA Plus Average for above average ERA Plus according to "A fans guide to Baseball Analytics"
ERA_Plus_Average_Adj=All_Pitchers_career_SUM[All_Pitchers_career_SUM['ERA_plus']>100].groupby('region').agg({'ERA_plus': ['mean']})
ERA_Plus_Average_Adj
# Out:
#               ERA_plus
#                   mean
# region
# Latin Born  132.803537
# Other       132.272383
# US Born     131.147537

# %%
#Pitcher Games
Games_Pitcher_Average=All_Pitchers_career_SUM.groupby('region').agg({'G_all': ['mean']})
Games_Pitcher_Average
# Out:
#                  G_all
#                   mean
# region
# Latin Born  134.086382
# Other       127.888889
# US Born     142.306687

# %%
#Pitcher Games for above 100 games
Games_Pitcher_Average_Adj=All_Pitchers_career_SUM[All_Pitchers_career_SUM['G_all']>100].groupby('region').agg({'G_all': ['mean']})
Games_Pitcher_Average_Adj
# Out:
#                  G_all
#                   mean
# region
# Latin Born  299.386667
# Other       277.109091
# US Born     296.248714

# %%
#Seasons Played for Pitchers
Seasons_Played_Pitcher=All_Pitchers_career_SUM.groupby('region').agg({'seasonsPlayed': ['mean']})
Seasons_Played_Pitcher
# Out:
#            seasonsPlayed
#                     mean
# region
# Latin Born      4.892276
# Other           4.708333
# US Born         5.409632

# %%
#Seasons Played for Pitchers who played more than one season
Seasons_Played_Pitcher_Adj=All_Pitchers_career_SUM[All_Pitchers_career_SUM['seasonsPlayed']>1].groupby('region').agg({'seasonsPlayed': ['mean']})
Seasons_Played_Pitcher_Adj
# Out:
#            seasonsPlayed
#                     mean
# region
# Latin Born      6.341702
# Other           6.037736
# US Born         6.669842

# %%
#ASG for pitchers that have played in more than one ASG
ASG_Pitcher_Adj=All_Pitchers_career_SUM[All_Pitchers_career_SUM['ASG']>0].groupby('region').agg({'ASG': ['mean']})
ASG_Pitcher_Adj
# Out:
#                  ASG
#                 mean
# region
# Latin Born  1.711111
# Other       1.250000
# US Born     1.655039

# %%
#Pitchers ASG
ASG_Pitcher=All_Pitchers_career_SUM.groupby('region').agg({'ASG': ['mean']})
ASG_Pitcher
# Out:
#                  ASG
#                 mean
# region
# Latin Born  0.078252
# Other       0.104167
# US Born     0.083252

# %%
PitcherWarAvg.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/PitcherWarAvg.csv')

# %%
PitcherWarAvgAdj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/PitcherWarAvgAdj.csv')

# %%
ERA_Plus_Average.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ERA_Plus_Average.csv')

# %%
ERA_Plus_Average_Adj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ERA_Plus_Average_Adj.csv')

# %%
Games_Pitcher_Average.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/Games_Pitcher_Average.csv')

# %%
Games_Pitcher_Average_Adj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/Games_Pitcher_Average_Adj.csv')

# %%
Seasons_Played_Pitcher.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/Seasons_Played_Pitcher.csv')

# %%
Seasons_Played_Pitcher_Adj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/Seasons_Played_Pitcher_Adj.csv')

# %%
ASG_Pitcher.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ASG_Pitcher.csv')

# %%
ASG_Pitcher_Adj.to_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/ASG_Pitcher_Adj.csv')
