# %% [markdown]
# # Task 6.2
# **This notebook will focus on relationship and statistical visualizations! Enjoy :)**

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
batters=pd.read_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/batters_sum_clean.csv')

# %%
pitchers=pd.read_csv(r'/Users/hillelkrief1/Desktop/CareerFoundry/Course 2 Data Immersion/Achievement 6/prepared data/aggregations/pitchers_sum_clean.csv')

# %%
batters.columns
# Out:
# Index(['playerID', 'WAR', 'HR', 'ASG', 'H', 'seasonsPlayed', 'region'], dtype='object')

# %%
pitchers.columns
# Out:
# Index(['playerID', 'WAR', 'ERA_plus', 'G_all', 'playerID.1', 'GP', 'region'], dtype='object')

# %%
batters=batters.drop(['playerID'], axis='columns')

# %%
pitchers=pitchers.drop(['playerID','playerID.1'],axis='columns')

# %%
batters['region'].value_counts()
# Out:
# US Born       4293
# Latin Born    1052
# Other           84
# Name: region, dtype: int64

# %%
pitchers['region'].value_counts()
# Out:
# US Born       5129
# Latin Born     984
# Other          144
# Name: region, dtype: int64

# %%
US_batters=batters[batters['region'] == 'US Born']

# %%
Latin_batters=batters[batters['region'] == 'Latin Born']

# %%
US_pitchers=pitchers[pitchers['region'] == 'US Born']

# %%
Latin_pitchers=pitchers[pitchers['region'] == 'Latin Born']

# %%
batters.columns
# Out:
# Index(['WAR', 'HR', 'ASG', 'H', 'seasonsPlayed', 'region'], dtype='object')

# %%
pitchers.columns
# Out:
# Index(['WAR', 'ERA_plus', 'G_all', 'GP', 'region'], dtype='object')

# %% [markdown]
# # Correlation Matrix

# %%
#US US_batters Matrix HeatMap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(US_batters.corr(), fignum=f.number) # type of plot
plt.xticks(range(US_batters.shape[1]), US_batters.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(US_batters.shape[1]), US_batters.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Latin_Batters Matrix HeatMap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Latin_batters.corr(), fignum=f.number) # type of plot
plt.xticks(range(Latin_batters.shape[1]), Latin_batters.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Latin_batters.shape[1]), Latin_batters.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
US_batters_corr=US_batters.corr()
US_batters.corr()
# Out:
#                     WAR        HR       ASG         H  seasonsPlayed
# WAR            1.000000  0.847207  0.672512  0.881930       0.675493
# HR             0.847207  1.000000  0.602733  0.852001       0.712527
# ASG            0.672512  0.602733  1.000000  0.579926       0.395720
# H              0.881930  0.852001  0.579926  1.000000       0.857820
# seasonsPlayed  0.675493  0.712527  0.395720  0.857820       1.000000

# %%
Latin_batters_corr=Latin_batters.corr()
Latin_batters.corr()
# Out:
#                     WAR        HR       ASG         H  seasonsPlayed
# WAR            1.000000  0.844508  0.713715  0.893177       0.677118
# HR             0.844508  1.000000  0.573135  0.826842       0.679706
# ASG            0.713715  0.573135  1.000000  0.629008       0.453482
# H              0.893177  0.826842  0.629008  1.000000       0.869003
# seasonsPlayed  0.677118  0.679706  0.453482  0.869003       1.000000

# %% [markdown]
# The batters heatmap shows us a **very strong** correlation between:
#     1. HR and WAR
#     2. H and WAR
#     3. H and HR
#     4. H and seasonsplayed
#
# It also shows us a **strong** correlation between:
#     1. ASG and WAR
#     2. ASG and HR
#     3. seasonsPlayed and WAR
#     4. ASG and H
#     5. seasonsPlayed and HR

# %%
#US_pitchers Matrix HeatMap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(US_pitchers.corr(), fignum=f.number) # type of plot
plt.xticks(range(US_pitchers.shape[1]), US_pitchers.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(US_pitchers.shape[1]), US_pitchers.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#Latin_pitchers Matrix HeatMap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Latin_pitchers.corr(), fignum=f.number) # type of plot
plt.xticks(range(Latin_pitchers.shape[1]), Latin_pitchers.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Latin_pitchers.shape[1]), Latin_pitchers.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
Latin_pitchers_corr=Latin_pitchers.corr()
Latin_pitchers.corr()
# Out:
#                WAR  ERA_plus     G_all        GP
# WAR       1.000000  0.226068  0.602648  0.580823
# ERA_plus  0.226068  1.000000  0.259047  0.123797
# G_all     0.602648  0.259047  1.000000  0.335418
# GP        0.580823  0.123797  0.335418  1.000000

# %%
US_pitchers_corr=US_pitchers.corr()
US_pitchers.corr()
# Out:
#                WAR  ERA_plus     G_all        GP
# WAR       1.000000  0.201191  0.635970  0.592339
# ERA_plus  0.201191  1.000000  0.248334  0.118951
# G_all     0.635970  0.248334  1.000000  0.371407
# GP        0.592339  0.118951  0.371407  1.000000

# %% [markdown]
# ERA Plus and WAR have a super weak correlation. Meaning the amount of runs that a pitcher gives up does not correlatate with how much he helps his team win

# %% [markdown]
# # Scatterplots

# %%
#ScatterPlot for US Batters
SP_US_batters=sns.lmplot(x = 'WAR', y = 'HR', data = US_batters)
SP_US_batters

# %%
#ScatterPlot for Latin Batters
SP_Latin_batters=sns.lmplot(x = 'WAR', y = 'HR', data = Latin_batters)
SP_Latin_batters

# %%
#ScatterPlot for US Pitchers
SP_US_pitchers=sns.lmplot(x = 'WAR', y = 'ERA_plus', data = US_pitchers)
SP_US_pitchers

# %%
#ScatterPlot for US Pitchers
SP_Latin_pitchers=sns.lmplot(x = 'WAR', y = 'ERA_plus', data = Latin_pitchers)
SP_Latin_pitchers

# %% [markdown]
# There is a weak positive relationship between ERA_plus and WAR and a very strong positive relationship between WAR and HR

# %%
PP_USB = sns.pairplot(US_batters)

# %%
PP_USP=sns.pairplot(US_pitchers)

# %%
PP_LB= sns.pairplot(Latin_batters)

# %%
PP_LP= sns.pairplot(Latin_pitchers)

# %% [markdown]
# # Catetgorical Plot

# %%
#There aren't any variables that make sense to preform a categorical plot
